# %% [markdown]
# <a href="https://colab.research.google.com/github/noname1711/computer_vision/blob/main/connect_google_drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a= 1
b=2
c= a+b
print(c)
# Out:
# 3

# %%
# kết nối với google drive
from google.colab import drive
drive.mount('/content/drive')    #lệnh này sẽ yêu cầu kết nối drive
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
import os
from google.colab.patches import cv2_imshow

# %%
path ='/content/drive/MyDrive/test_gg_colab'    #đường dẫn bất kì trên drive
#hiển thị tất cả thư mục hoặc file
os.listdir(path)
# Out:
# ['ssstik.io_1687409377198.mp3',
#  'z5208104843458_b1f942a78b55b7ef4aca1d82f4d030ed.jpg',
#  'z5208104843558_ace3673d9ad5a3ec0ca35419d5c65cf2.jpg',
#  'z5208351346020_58ed5991cd58c67c09553c2f54fcaa41.jpg',
#  'z5216127496692_5d01cd898d27c06693bf2741c80ee836.jpg',
#  'z5230227978776_5644d3c25c9aad60f314075315e76910.jpg',
#  'z5239112963639_a79f3b728e9cee6723e90376b6e88c4c.jpg',
#  'z5252351596535_6895da8ab85d58a6aeef8eb589827b87.jpg',
#  'X-WORLD-PRIVATE—FILE—DONT MOVE AND DELETE-1714329224225',
#  'Qunltichnh.zip']

# %%
#hiển thị một ảnh
img = cv2.imread(path + '/z5208104843458_b1f942a78b55b7ef4aca1d82f4d030ed.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x960>
